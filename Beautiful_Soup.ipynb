# %% [markdown]
# #**Índia**
# ---

# %%
#Importa as funções de Beautiful Soup que vão parsear os dados obtidos do website
from bs4 import BeautifulSoup
#Importa a biblioteca usada para carregar o website
import requests

# %%
#Especifica a url e carrega o website e retorna o html para a variável 'page'
wiki = 'https://en.wikipedia.org/wiki/List_of_state_and_union_territory_capitals_in_India'
r = requests.get(wiki)

# %%
#Parseia a página ao beautifulsoup
soup = BeautifulSoup(r.content, 'html.parser')

# %%
soup

# %%
soup.a

# %%
soup.title.string

# %%
soup.find_all('a')

# %%
links = soup.find_all('a')
for link in links:
  print(link.get('href'))

# %%
tabelas = soup.find_all('table')
soup.find_all('table', class_='wikitable sortable plainrowheaders')

# %%
for c in tabelas:
  print(c.td.text)

# %% [markdown]
# #**Medium**
# ---

# %%
#importando as libs
from urllib.request import urlopen
#definindo a url alvo
url = 'http://pythonscraping.com/pages/page1.html'
#requisição para usar o html
html = urlopen(url)
#verificando o html
html.read()

# %%
from bs4 import BeautifulSoup
url = 'https://www.python.org'
html = urlopen(url)
#convertendo em bs
soup = BeautifulSoup(html, 'lxml')
#imprimindo uma parte do código
soup.title

# %%
#encontrando uma tag específica
h1 = soup.find_all('h1')
#contando o nº de ocorrências dessa tag
print(f'Há {len(h1)} ocorrências de h1')

# %%
#encontra a primeira ocorrência de uma tag
soup.find('h1')

# %%
#trocando url
url = 'https://www.wikipedia.org/'
html = urlopen(url)
soup = BeautifulSoup(html, 'lxml')
print(soup.find('span', class_="central-textlogo__image sprite svg-Wikipedia_wordmark"))
print(soup.find('span', class_="central-textlogo__image sprite svg-Wikipedia_wordmark").text)
#selecionando id (língua)
print(soup.find(id='js-link-box-pt').text)

# %%
print(soup.find(id='js-link-box-pt'))

# %%
#Selecionar todas as tags strong dentro de div
print(soup.select('div strong'))
print('\n')
#Agora todas as tags input dentro de forms dentro de divs
print(soup.select('div form input'))

# %%
#Aqui selecionamos pela classe pure-form todos os inputs dentro dela
print(soup.select('.pure-form input'))
print('\n')
#Aqui selecionamos pela classe pure-form todos os inputs dentro dela
print(soup.select('#search-form'))

# %% [markdown]
# #**Projeto**
# ---
# Importar uma lista dos 250 filmes mais bem listados do IMDB

# %%
#importando as libs
import pandas as pd
from urllib.request import urlopen
from urllib.error import HTTPError
from urllib.error import URLError
from bs4 import BeautifulSoup

# %%
#URL base
url = 'https://www.imdb.com/chart/top'

# %%
#Tratando erros
try:
  html = urlopen(url)
except HTTPError as e:
  #erros http
  print(e)
except URLError as e:
  print("The server couldn't be found!")

# %%
#Sopa
soup = BeautifulSoup(html, 'lxml')

#Imprimindo o título
filmes = soup.select('.lister-list tr')

# %%
#Fazendo as listas
titulos = []
diretores_escritores = []
anos = []
ratings = []

for filme in filmes:
  titulos.append(filme.find('td', class_='titleColumn').find('a').get_text())
  diretores_escritores.append(filme.find('td', class_='titleColumn').find('a')['title'])
  anos.append(filme.find('td', class_='titleColumn').find('span').get_text()[1:5])
  ratings.append(filme.find('td', class_='imdbRating').find('strong').get_text())

# %%
#pandas dataframe
df = pd.DataFrame({
    'Título' : titulos,
    'Diretores_Escritores' : diretores_escritores,
    'Ano' : anos,
    'Nota' : ratings})
df.head()

# %%
#criando um csv pelo pandas
from google.colab import files
df.to_csv('imdb_250.csv')
files.download('imdb_250.csv')

# %% [markdown]
# #**Ibov - B3**
# ---

# %%
#link base: http://www.b3.com.br/pt_br/produtos-e-servicos/negociacao/renda-variavel/fundos-de-investimentos/fii/fiis-listados/
from urllib.request import urlopen
import urllib
from bs4 import BeautifulSoup
#link
url = 'http://bvmf.bmfbovespa.com.br/Fundos-Listados/FundosListados.aspx?tipoFundo=imobiliario&Idioma=pt-br'

html = urlopen(url)
soup = BeautifulSoup(html, 'html.parser')

tabela = soup.select('table tr')

# %%
razao = list()
fundo = list()
segmento = list()
codigo = list()

for c in range(1, len(tabela)):
  razao.append(tabela[c].find('td').get_text())
  fundo.append(tabela[c].find('td').find_next('td').get_text())
  segmento.append(tabela[c].find('td').find_next('td').find_next('td').get_text())
  codigo.append(tabela[c].find('td').find_next('td').find_next('td').find_next('td').get_text())

# %%
cnpj = list()
classificação = list()
site = list()

for c in range(1, len(tabela)):
  link = 'http://bvmf.bmfbovespa.com.br/Fundos-Listados/' + tabela[c].find('a')['href']
  outros = urlopen(link)
  soup_others = BeautifulSoup(outros, 'html.parser')
  t = soup_others.find('tbody')
  #CNPJ
  try:
    cnpj.append(t.find(id='ctl00_contentPlaceHolderConteudo_ucFundoDetalhes_lblCNPJ').get_text())    
  except:
    cnpj.append('')
  #Classificação Setorial
  try:
    classificação.append(t.find(id='ctl00_contentPlaceHolderConteudo_ucFundoDetalhes_lblClassificacaoSetorial').get_text())    
  except:
    classificação.append('')
  #Site
  try:
    site.append(t.find(id='ctl00_contentPlaceHolderConteudo_ucFundoDetalhes_linhaSite').find('a')['href'])
  except:
    site.append('')

# %%
#classificação.append(t.find('tr').find_next('tr').find_next('tr').find_next('tr').find('td').find_next('td').get_text())
#site.append(t.find('tr').find_next('tr').find_next('tr').find_next('tr').find_next('tr').find('a')['href'])
#print(t.find('tr').find_next('tr').find_next('tr').find('td').find_next('td').get_text())

# %%
#pandas
import pandas as pd
df = pd.DataFrame({
    'Razão Social' : razao,
    'Fundo' : fundo,
    'Segmento' : segmento,
    'Código' : codigo,
    'CNPJ' : cnpj,
    'Classificação Setorial' : classificação,
    'Site' : site})
df.head()

# %%
from google.colab import files
df.to_csv('B3-Ibov-att.csv')
files.download('B3-Ibov-att.csv')

# %% [markdown]
# #**Ibov - B3 (2)**
# ---

# %%
#link base: http://www.b3.com.br/pt_br/produtos-e-servicos/negociacao/renda-variavel/fundos-de-investimentos/fii/fiis-listados/
import json
from urllib.request import urlopen
from bs4 import BeautifulSoup

#link
url = 'http://bvmf.bmfbovespa.com.br/Fundos-Listados/FundosListados.aspx?tipoFundo=imobiliario&Idioma=pt-br'

html = urlopen(url)
soup = BeautifulSoup(html, 'html.parser')

tabela = soup.select('table tr')

# %%
FII = list()
dic = dict()

for c in range(1, len(tabela)):
  proventos = list()
  dicprovento = dict()
  valor = list()
  #abrindo cada link individualmente
  link = 'http://bvmf.bmfbovespa.com.br/Fundos-Listados/' + tabela[c].find('a')['href']
  outros = urlopen(link)
  soup_others = BeautifulSoup(outros, 'html.parser')

  #coleta dos dados principais
  try: #informações gerais
    dic['fundo'] = soup_others.find(id='ctl00_contentPlaceHolderConteudo_ucEventosCorporativos_lblNomeFundoValor').get_text()
    dic['segmento'] = soup_others.find(id='ctl00_contentPlaceHolderConteudo_ucEventosCorporativos_lblSegmentoValor').get_text()
    dic['codigo'] = soup_others.find(id='ctl00_contentPlaceHolderConteudo_ucEventosCorporativos_lblCodigoValor').get_text()
    dic['lote'] = soup_others.find(id='ctl00_contentPlaceHolderConteudo_ucEventosCorporativos_lblLotePadraoNegValor').get_text()
    dic['cotacao'] = soup_others.find(id='ctl00_contentPlaceHolderConteudo_ucEventosCorporativos_lblCotacaoUnitariaValor').get_text()
    dic['qtcotas'] = soup_others.find(id='ctl00_contentPlaceHolderConteudo_ucEventosCorporativos_lblQtdeCotasValor').get_text()
    dic['formacotas'] = soup_others.find(id='ctl00_contentPlaceHolderConteudo_ucEventosCorporativos_lblFormaCotasValor').get_text()
  except:
    continue

  #coleta dos proventos
  prov = soup_others.select('tbody tr')
  for c in range(16, len(prov)):
    trat = prov[c].find('td').get_text()  
    if trat == 'RENDIMENTO':    
      try:
        dicprovento['isin'] = prov[c].find('td', align='left').get_text()
        dicprovento['deliberado_em'] = prov[c].find('td', align='center').get_text()
        dicprovento['valor'] = prov[c].find('td', align='right').get_text()
        dicprovento['relativo'] = prov[c].find('td', align='center').find_next('td').find_next('td', align='center').get_text()
        dicprovento['inicio_pag'] = prov[c].find('td', align='center').find_next('td').find_next('td', align='center').find_next('td').get_text()
      except:
        continue
    else:
      continue
    #colocando cada linha dentro de um dict, passando pra lista e limpando para coletar dados de outra linha
    proventos.append(dicprovento.copy())
    dicprovento.clear()


  #adicionando todas as informações dentro de um dict, colocando na lista dos FII's e limpando para adicionar mais dados
  if len(proventos) >= 1:
    dic['proventos'] = proventos[:]
  FII.append(dic.copy())
  dic.clear()
#convertendo p/ json file
with open('fiis.json', 'w') as json_file:
  json.dump(FII, json_file, indent=2)

# %%
#lendo o arquivo
# !cat fiis.json
# Out:
# [
#   {
#     "fundo": "FII AUTONOMY",
#     "segmento": "BOLSA",
#     "codigo": "AIEC",
#     "lote": "1",
#     "cotacao": "19/02/2020",
#     "qtcotas": "4.825.000",
#     "formacotas": "Escritural - BANCO MODAL S.A"
#   },
#   {
#     "fundo": "FII BC FUND ",
#     "segmento": "BOLSA",
#     "codigo": "BRCR",
#     "lote": "1",
#     "cotacao": "01/10/2012",
#     "qtcotas": "26.638.202",
#     "formacotas": "Escritural - BTG PACTUAL SERVI\u00c7OS FINANC. S.A. DTVM"
#   },
#   {
#     "fundo": "FII EXCELLEN",
#     "segmento": "BOLSA",
#     "codigo": "FEXC",
#     "lote": "1",
#     "cotacao": "02/05/2017",
#     "qtcotas": "3.421.945",
#     "formacotas": "Escritural - BTG PACTUAL SERVI\u00c7OS FINANC. S.A. DTVM",
#     "proventos": [
#       {
#         "isin": "BRFEXCCTF007",
#         "deliberado_em": "08/09/2020",
#         "valor": "0,50000000000",
#         "relativo": "Agosto/2020",
#         "inicio_pag": "15/09/2020"
#       },
#       {
#         "isin": "BRFEXCR10M19",
#         "deliberado_em": "08/09/2020",
#         "valor": "0,01550168000",
#         "relativo": "Agosto/2020",
#         "inicio_pag": "15/09/2020"
#       },
#       {
#         "isin": "BRFEXCR11M18",
#         "deliberado_em": "08/09/2020",
#         "valor": "0,00817635000",
#         "relativo": "Agosto/2020",
#         "inicio_pag": "15/09/2020"
#       },
#       {
#         "isin": "BRFEXCR12M17",
#         "deliberado_em": "08/09/2020",
#         "valor": "0,00130061000",
#         "relativo": "Agosto/2020",
#         "inicio_pag": "15/09/2020"
#       },
#       {
#         "isin": "BRFEXCCTF007",
#         "deliberado_em": "07/08/2020",
#         "valor": "0,60000000000",
#         "relativo": "Julho/2020",
#         "inicio_pag": "14/08/2020"
#       },
#       {
#         "isin": "BRFEXCCTF007",
#         "deliberado_em": "07/07/2020",
#         "valor": "1,15000000000",
#         "relativo": "Junho/2020",
#         "inicio_pag": "14/07/2020"
#       },
#       {
#         "isin": "BRFEXCCTF007",
#         "deliberado_em": "05/06/2020",
#         "valor": "0,80000000000",
#         "relativo": "Maio/2020",
#         "inicio_pag": "15/06/2020"
#       },
#       {
#         "isin": "BRFEXCCTF007",
#         "deliberado_em": "08/05/2020",
#         "valor": "0,85000000000",
#         "relativo": "Abril/2020",
#         "inicio_pag": "15/05/2020"
#       },
#       {
#         "isin": "BRFEXCCTF007",
#         "deliberado_em": "07/04/2020",
#         "valor": "0,95000000000",
#         "relativo": "Mar\u00e7o/2020",
#         "inicio_pag": "15/04/2020"
#       },
#       {
#         "isin": "BRFEXCCTF007",
#         "deliberado_em": "06/03/2020",
#         "valor": "0,70000000000",
#         "relativo": "Fevereiro/2020",
#         "inicio_pag": "13/03/2020"
#       },
#       {
#         "isin": "BRFEXCCTF007",
#         "deliberado_em": "07/02/2020",
#         "valor": "0,70000000000",
#         "relativo": "Janeiro/2020",
#         "inicio_pag": "14/02/2020"
#       },
#       {
#         "isin": "BRFEXCCTF007",
#         "deliberado_em": "08/01/2020",
#         "valor": "0,64000000000",
#         "relativo": "Dezembro/2019",
#         "inicio_pag": "15/01/2020"
#       },
#       {
#         "isin": "BRFEXCCTF007",
#         "deliberado_em": "06/12/2019",
#         "valor": "0,60000000000",
#         "relativo": "Novembro/2019",
#         "inicio_pag": "13/12/2019"
#       },
#       {
#         "isin": "BRFEXCCTF007",
#         "deliberado_em": "07/11/2019",
#         "valor": "0,60000000000",
#         "relativo": "Outubro/2019",
#         "inicio_pag": "14/11/2019"
#       },
#       {
#         "isin": "BRFEXCR09M12",
#         "deliberado_em": "07/11/2019",
#         "valor": "0,60000000000",
#         "relativo": "Outubro/2019",
#         "inicio_pag": "14/11/2019"
#       },
#       {
#         "isin": "BRFEXCCTF007",
#         "deliberado_em": "07/10/2019",
#         "valor": "0,65000000000",
#         "relativo": "Setembro/2019",
#         "inicio_pag": "14/10/2019"
#       },
#       {
#         "isin": "BRFEXCR09M12",
#         "deliberado_em": "07/10/2019",
#         "valor": "0,65000000000",
#         "relativo": "Setembro/2019",
#         "inicio_pag": "14/10/2019"
#       }
#     ]
#   },
#   {
#     "fundo": "FII BC FFII ",
#     "segmento": "BOLSA",
#     "codigo": "BCFF",
#     "lote": "1",
#     "cotacao": "01/12/2017",
#     "qtcotas": "20.562.973",
#     "formacotas": "Escritural - BTG PACTUAL SERVI\u00c7OS FINANC. S.A. DTVM",
#     "proventos": [
#       {
#         "isin": "BRBCFFR27M15",
#         "deliberado_em": "07/11/2019",
#         "valor": "0,01218832900",
#         "relativo": "Outubro/2019",
#         "inicio_pag": "14/11/2019"
#       },
#       {
#         "isin": "BRBCFFCTF000",
#         "deliberado_em": "07/10/2019",
#         "valor": "0,57000000000",
#         "relativo": "Setembro/2019",
#         "inicio_pag": "14/10/2019"
#       }
#     ]
#   },
#   {
#     "fundo": "FII CAMPUSFL",
#     "segmento": "BOLSA",
#     "codigo": "FCFL",
#     "lote": "1",
#     "cotacao": "01/06/2017",
#     "qtcotas": "3.474.010",
#     "formacotas": "Escritural - BTG PACTUAL SERVI\u00c7OS FINANC. S.A. DTVM",
#     "proventos": [
#       {
#         "isin": "BRFCFLCTF009",
#         "deliberado_em": "18/09/2020",
#         "valor": "0,56510752700",
#         "relativo": "Agosto/2020",
#         "inicio_pag": "25/09/2020"
#       },
#       {
#         "isin": "BRFCFLCTF009",
#         "deliberado_em": "18/08/2020",
#         "valor": "0,56347658700",
#         "relativo": "Julho/2020",
#         "inicio_pag": "25/08/2020"
#       },
#       {
#         "isin": "BRFCFLCTF009",
#         "deliberado_em": "17/07/2020",
#         "valor": "0,57891161500",
#         "relativo": "Junho/2020",
#         "inicio_pag": "24/07/2020"
#       },
#       {
#         "isin": "BRFCFLR01M13",
#         "deliberado_em": "17/07/2020",
#         "valor": "0,08859905100",
#         "relativo": "Junho/2020",
#         "inicio_pag": "24/07/2020"
#       },
#       {
#         "isin": "BRFCFLCTF009",
#         "deliberado_em": "18/06/2020",
#         "valor": "0,51190274800",
#         "relativo": "Maio/2020",
#         "inicio_pag": "25/06/2020"
#       },
#       {
#         "isin": "BRFCFLCTF009",
#         "deliberado_em": "18/05/2020",
#         "valor": "0,50000000000",
#         "relativo": "Abril/2020",
#         "inicio_pag": "25/05/2020"
#       },
#       {
#         "isin": "BRFCFLCTF009",
#         "deliberado_em": "16/04/2020",
#         "valor": "0,52000000000",
#         "relativo": "Mar\u00e7o/2020",
#         "inicio_pag": "24/04/2020"
#       },
#       {
#         "isin": "BRFCFLCTF009",
#         "deliberado_em": "18/03/2020",
#         "valor": "0,57700000000",
#         "relativo": "Fevereiro/2020",
#         "inicio_pag": "25/03/2020"
#       },
#       {
#         "isin": "BRFCFLCTF009",
#         "deliberado_em": "14/02/2020",
#         "valor": "0,58000000000",
#         "relativo": "Janeiro/2020",
#         "inicio_pag": "21/02/2020"
#       },
#       {
#         "isin": "BRFCFLCTF009",
#         "deliberado_em": "17/01/2020",
#         "valor": "0,29064819100",
#         "relativo": "Dezembro/2019",
#         "inicio_pag": "24/01/2020"
#       },
#       {
#         "isin": "BRFCFLCTF009",
#         "deliberado_em": "16/12/2019",
#         "valor": "0,62148942200",
#         "relativo": "Novembro/2019",
#         "inicio_pag": "23/12/2019"
#       },
#       {
#         "isin": "BRFCFLCTF009",
#         "deliberado_em": "14/11/2019",
#         "valor": "0,64877023000",
#         "relativo": "Outubro/2019",
#         "inicio_pag": "25/11/2019"
#       },
#       {
#         "isin": "BRFCFLCTF009",
#         "deliberado_em": "18/10/2019",
#         "valor": "0,64420459200",
#         "relativo": "Setembro/2019",
#         "inicio_pag": "25/10/2019"
#       }
#     ]
#   },
#   {
#     "fundo": "FII CENESP  ",
#     "segmento": "BOLSA",
#     "codigo": "CNES",
#     "lote": "1",
#     "cotacao": "02/05/2017",
#     "qtcotas": "2.949.248",
#     "formacotas": "Escritural - BTG PACTUAL SERVI\u00c7OS FINANC. S.A. DTVM",
#     "proventos": [
#       {
#         "isin": "BRCNESCTF001",
#         "deliberado_em": "22/09/2020",
#         "valor": "0,23219696300",
#         "relativo": "Agosto/2020",
#         "inicio_pag": "29/09/2020"
#       },
#       {
#         "isin": "BRCNESCTF001",
#         "deliberado_em": "21/08/2020",
#         "valor": "0,34123316800",
#         "relativo": "Julho/2020",
#         "inicio_pag": "28/08/2020"
#       },
#       {
#         "isin": "BRCNESCTF001",
#         "deliberado_em": "23/07/2020",
#         "valor": "0,13625298300",
#         "relativo": "Junho/2020",
#         "inicio_pag": "30/07/2020"
#       },
#       {
#         "isin": "BRCNESCTF001",
#         "deliberado_em": "22/06/2020",
#         "valor": "0,29551618500",
#         "relativo": "Maio/2020",
#         "inicio_pag": "29/06/2020"
#       },
#       {
#         "isin": "BRCNESCTF001",
#         "deliberado_em": "21/05/2020",
#         "valor": "0,16531493700",
#         "relativo": "Abril/2020",
#         "inicio_pag": "28/05/2020"
#       },
#       {
#         "isin": "BRCNESCTF001",
#         "deliberado_em": "22/04/2020",
#         "valor": "0,53936007700",
#         "relativo": "Mar\u00e7o/2020",
#         "inicio_pag": "29/04/2020"
#       },
#       {
#         "isin": "BRCNESCTF001",
#         "deliberado_em": "23/03/2020",
#         "valor": "0,11127263900",
#         "relativo": "Fevereiro/2020",
#         "inicio_pag": "30/03/2020"
#       },
#       {
#         "isin": "BRCNESCTF001",
#         "deliberado_em": "18/02/2020",
#         "valor": "0,17715492200",
#         "relativo": "Janeiro/2020",
#         "inicio_pag": "27/02/2020"
#       },
#       {
#         "isin": "BRCNESCTF001",
#         "deliberado_em": "23/01/2020",
#         "valor": "0,19208162500",
#         "relativo": "Dezembro/2019",
#         "inicio_pag": "30/01/2020"
#       },
#       {
#         "isin": "BRCNESCTF001",
#         "deliberado_em": "18/12/2019",
#         "valor": "0,10516057600",
#         "relativo": "Novembro/2019",
#         "inicio_pag": "27/12/2019"
#       },
#       {
#         "isin": "BRCNESCTF001",
#         "deliberado_em": "21/11/2019",
#         "valor": "0,19092041400",
#         "relativo": "Outubro/2019",
#         "inicio_pag": "28/11/2019"
#       },
#       {
#         "isin": "BRCNESCTF001",
#         "deliberado_em": "23/10/2019",
#         "valor": "0,19717332300",
#         "relativo": "Setembro/2019",
#         "inicio_pag": "30/10/2019"
#       }
#     ]
#   },
#   {
#     "fundo": "FII CEO CCP ",
#     "segmento": "BOLSA",
#     "codigo": "CEOC",
#     "lote": "1",
#     "cotacao": "01/06/2017",
#     "qtcotas": "1.815.696",
#     "formacotas": "Escritural - BTG PACTUAL SERVI\u00c7OS FINANC. S.A. DTVM",
#     "proventos": [
#       {
#         "isin": "BRCEOCCTF003",
#         "deliberado_em": "08/09/2020",
#         "valor": "0,57958341000",
#         "relativo": "Agosto/2020",
#         "inicio_pag": "15/09/2020"
#       },
#       {
#         "isin": "BRCEOCCTF003",
#         "deliberado_em": "07/08/2020",
#         "valor": "0,57154097900",
#         "relativo": "Julho/2020",
#         "inicio_pag": "14/08/2020"
#       },
#       {
#         "isin": "BRCEOCCTF003",
#         "deliberado_em": "07/07/2020",
#         "valor": "0,56935902800",
#         "relativo": "Junho/2020",
#         "inicio_pag": "14/07/2020"
#       },
#       {
#         "isin": "BRCEOCCTF003",
#         "deliberado_em": "05/06/2020",
#         "valor": "0,56687362300",
#         "relativo": "Maio/2020",
#         "inicio_pag": "15/06/2020"
#       },
#       {
#         "isin": "BRCEOCCTF003",
#         "deliberado_em": "08/05/2020",
#         "valor": "0,52877852900",
#         "relativo": "Abril/2020",
#         "inicio_pag": "15/05/2020"
#       },
#       {
#         "isin": "BRCEOCCTF003",
#         "deliberado_em": "07/04/2020",
#         "valor": "0,50884764200",
#         "relativo": "Mar\u00e7o/2020",
#         "inicio_pag": "15/04/2020"
#       },
#       {
#         "isin": "BRCEOCCTF003",
#         "deliberado_em": "06/03/2020",
#         "valor": "0,56127065300",
#         "relativo": "Fevereiro/2020",
#         "inicio_pag": "13/03/2020"
#       },
#       {
#         "isin": "BRCEOCCTF003",
#         "deliberado_em": "07/02/2020",
#         "valor": "0,55864276200",
#         "relativo": "Janeiro/2020",
#         "inicio_pag": "14/02/2020"
#       },
#       {
#         "isin": "BRCEOCCTF003",
#         "deliberado_em": "08/01/2020",
#         "valor": "0,56831858900",
#         "relativo": "Dezembro/2019",
#         "inicio_pag": "15/01/2020"
#       },
#       {
#         "isin": "BRCEOCCTF003",
#         "deliberado_em": "06/12/2019",
#         "valor": "0,56059936700",
#         "relativo": "Novembro/2019",
#         "inicio_pag": "13/12/2019"
#       },
#       {
#         "isin": "BRCEOCCTF003",
#         "deliberado_em": "07/11/2019",
#         "valor": "0,57024173000",
#         "relativo": "Outubro/2019",
#         "inicio_pag": "14/11/2019"
#       },
#       {
#         "isin": "BRCEOCCTF003",
#         "deliberado_em": "07/10/2019",
#         "valor": "0,57127451400",
#         "relativo": "Setembro/2019",
#         "inicio_pag": "14/10/2019"
#       }
#     ]
#   },
#   {
#     "fundo": "FII BM THERA",
#     "segmento": "BOLSA",
#     "codigo": "THRA",
#     "lote": "1",
#     "cotacao": "01/06/2017",
#     "qtcotas": "1.472.728",
#     "formacotas": "Escritural - BTG PACTUAL SERVI\u00c7OS FINANC. S.A. DTVM",
#     "proventos": [
#       {
#         "isin": "BRTHRACTF007",
#         "deliberado_em": "08/09/2020",
#         "valor": "0,36011856200",
#         "relativo": "Agosto/2020",
#         "inicio_pag": "15/09/2020"
#       },
#       {
#         "isin": "BRTHRACTF007",
#         "deliberado_em": "07/08/2020",
#         "valor": "0,45814316000",
#         "relativo": "Julho/2020",
#         "inicio_pag": "14/08/2020"
#       },
#       {
#         "isin": "BRTHRACTF007",
#         "deliberado_em": "07/07/2020",
#         "valor": "0,78826278100",
#         "relativo": "Junho/2020",
#         "inicio_pag": "14/07/2020"
#       },
#       {
#         "isin": "BRTHRACTF007",
#         "deliberado_em": "05/06/2020",
#         "valor": "0,78512512100",
#         "relativo": "Maio/2020",
#         "inicio_pag": "15/06/2020"
#       },
#       {
#         "isin": "BRTHRACTF007",
#         "deliberado_em": "08/05/2020",
#         "valor": "0,46635729000",
#         "relativo": "Abril/2020",
#         "inicio_pag": "15/05/2020"
#       },
#       {
#         "isin": "BRTHRACTF007",
#         "deliberado_em": "07/04/2020",
#         "valor": "0,51746426300",
#         "relativo": "Mar\u00e7o/2020",
#         "inicio_pag": "15/04/2020"
#       },
#       {
#         "isin": "BRTHRACTF007",
#         "deliberado_em": "06/03/2020",
#         "valor": "0,63760612200",
#         "relativo": "Fevereiro/2020",
#         "inicio_pag": "13/03/2020"
#       },
#       {
#         "isin": "BRTHRACTF007",
#         "deliberado_em": "07/02/2020",
#         "valor": "0,66353711600",
#         "relativo": "Janeiro/2020",
#         "inicio_pag": "14/02/2020"
#       },
#       {
#         "isin": "BRTHRACTF007",
#         "deliberado_em": "08/01/2020",
#         "valor": "0,73516356000",
#         "relativo": "Dezembro/2019",
#         "inicio_pag": "15/01/2020"
#       },
#       {
#         "isin": "BRTHRACTF007",
#         "deliberado_em": "06/12/2019",
#         "valor": "0,61282703900",
#         "relativo": "Novembro/2019",
#         "inicio_pag": "13/12/2019"
#       },
#       {
#         "isin": "BRTHRACTF007",
#         "deliberado_em": "07/11/2019",
#         "valor": "0,62756541600",
#         "relativo": "Outubro/2019",
#         "inicio_pag": "14/11/2019"
#       },
#       {
#         "isin": "BRTHRACTF007",
#         "deliberado_em": "07/10/2019",
#         "valor": "0,53622211900",
#         "relativo": "Setembro/2019",
#         "inicio_pag": "14/10/2019"
#       }
#     ]
#   },
#   {
#     "fundo": "FII ALMIRANT",
#     "segmento": "MB",
#     "codigo": "FAMB",
#     "lote": "1",
#     "cotacao": "16/12/2002",
#     "qtcotas": "104.800",
#     "formacotas": "Escritural - BTG PACTUAL SERVI\u00c7OS FINANC. S.A. DTVM",
#     "proventos": [
#       {
#         "isin": "BRFAMBCTF018",
#         "deliberado_em": "30/09/2020",
#         "valor": "25,28496221300",
#         "relativo": "Setembro/2020",
#         "inicio_pag": "14/10/2020"
#       },
#       {
#         "isin": "BRFAMBCTF018",
#         "deliberado_em": "31/08/2020",
#         "valor": "26,13016335800",
#         "relativo": "Agosto/2020",
#         "inicio_pag": "14/09/2020"
#       },
#       {
#         "isin": "BRFAMBCTF018",
#         "deliberado_em": "31/07/2020",
#         "valor": "25,92225925500",
#         "relativo": "Julho/2020",
#         "inicio_pag": "13/08/2020"
#       },
#       {
#         "isin": "BRFAMBCTF018",
#         "deliberado_em": "30/06/2020",
#         "valor": "32,00010124000",
#         "relativo": "Junho/2020",
#         "inicio_pag": "13/07/2020"
#       },
#       {
#         "isin": "BRFAMBCTF018",
#         "deliberado_em": "29/05/2020",
#         "valor": "32,17864198400",
#         "relativo": "Maio/2020",
#         "inicio_pag": "12/06/2020"
#       },
#       {
#         "isin": "BRFAMBCTF018",
#         "deliberado_em": "30/04/2020",
#         "valor": "30,09074541900",
#         "relativo": "Abril/2020",
#         "inicio_pag": "14/05/2020"
#       },
#       {
#         "isin": "BRFAMBCTF018",
#         "deliberado_em": "31/03/2020",
#         "valor": "29,74824685100",
#         "relativo": "Mar\u00e7o/2020",
#         "inicio_pag": "14/04/2020"
#       },
#       {
#         "isin": "BRFAMBCTF018",
#         "deliberado_em": "28/02/2020",
#         "valor": "28,42592948400",
#         "relativo": "Fevereiro/2020",
#         "inicio_pag": "12/03/2020"
#       },
#       {
#         "isin": "BRFAMBCTF018",
#         "deliberado_em": "31/01/2020",
#         "valor": "29,04403263300",
#         "relativo": "Janeiro/2020",
#         "inicio_pag": "13/02/2020"
#       },
#       {
#         "isin": "BRFAMBCTF018",
#         "deliberado_em": "30/12/2019",
#         "valor": "29,67711230900",
#         "relativo": "Dezembro/2019",
#         "inicio_pag": "14/01/2020"
#       },
#       {
#         "isin": "BRFAMBCTF018",
#         "deliberado_em": "29/11/2019",
#         "valor": "29,15921956100",
#         "relativo": "Novembro/2019",
#         "inicio_pag": "12/12/2019"
#       },
#       {
#         "isin": "BRFAMBCTF018",
#         "deliberado_em": "31/10/2019",
#         "valor": "28,25290019000",
#         "relativo": "Outubro/2019",
#         "inicio_pag": "13/11/2019"
#       }
#     ]
#   },
#   {
#     "fundo": "FII GALERIA ",
#     "segmento": "BOLSA",
#     "codigo": "EDGA",
#     "lote": "1",
#     "cotacao": "02/05/2017",
#     "qtcotas": "3.812.055",
#     "formacotas": "Nominativa - BTG PACTUAL SERVI\u00c7OS FINANC. S.A. DTVM",
#     "proventos": [
#       {
#         "isin": "BREDGACTF001",
#         "deliberado_em": "23/09/2020",
#         "valor": "0,11745060300",
#         "relativo": "Agosto/2020",
#         "inicio_pag": "30/09/2020"
#       },
#       {
#         "isin": "BREDGACTF001",
#         "deliberado_em": "24/08/2020",
#         "valor": "0,25682201800",
#         "relativo": "Julho/2020",
#         "inicio_pag": "31/08/2020"
#       },
#       {
#         "isin": "BREDGACTF001",
#         "deliberado_em": "24/07/2020",
#         "valor": "0,05302320900",
#         "relativo": "Junho/2020",
#         "inicio_pag": "31/07/2020"
#       },
#       {
#         "isin": "BREDGACTF001",
#         "deliberado_em": "23/06/2020",
#         "valor": "0,08899737000",
#         "relativo": "Maio/2020",
#         "inicio_pag": "30/06/2020"
#       },
#       {
#         "isin": "BREDGACTF001",
#         "deliberado_em": "22/05/2020",
#         "valor": "0,11254005100",
#         "relativo": "Abril/2020",
#         "inicio_pag": "29/05/2020"
#       },
#       {
#         "isin": "BREDGACTF001",
#         "deliberado_em": "23/04/2020",
#         "valor": "0,11518205200",
#         "relativo": "Mar\u00e7o/2020",
#         "inicio_pag": "30/04/2020"
#       },
#       {
#         "isin": "BREDGACTF001",
#         "deliberado_em": "24/03/2020",
#         "valor": "0,16065220200",
#         "relativo": "Fevereiro/2020",
#         "inicio_pag": "31/03/2020"
#       },
#       {
#         "isin": "BREDGACTF001",
#         "deliberado_em": "19/02/2020",
#         "valor": "0,18692716900",
#         "relativo": "Janeiro/2020",
#         "inicio_pag": "28/02/2020"
#       },
#       {
#         "isin": "BREDGACTF001",
#         "deliberado_em": "24/01/2020",
#         "valor": "0,19684063000",
#         "relativo": "Dezembro/2019",
#         "inicio_pag": "31/01/2020"
#       },
#       {
#         "isin": "BREDGACTF001",
#         "deliberado_em": "19/12/2019",
#         "valor": "0,20000000000",
#         "relativo": "Novembro/2019",
#         "inicio_pag": "30/12/2019"
#       },
#       {
#         "isin": "BREDGACTF001",
#         "deliberado_em": "22/11/2019",
#         "valor": "0,21000000000",
#         "relativo": "Outubro/2019",
#         "inicio_pag": "29/11/2019"
#       },
#       {
#         "isin": "BREDGACTF001",
#         "deliberado_em": "24/10/2019",
#         "valor": "0,20000000000",
#         "relativo": "Setembro/2019",
#         "inicio_pag": "31/10/2019"
#       }
#     ]
#   },
#   {
#     "fundo": "FII ELDORADO",
#     "segmento": "MB",
#     "codigo": "ELDO",
#     "lote": "1",
#     "cotacao": "12/03/2014",
#     "qtcotas": "787.256",
#     "formacotas": "Escritural - RIO BRAVO INVESTIMENTOS DTVM S.A.",
#     "proventos": [
#       {
#         "isin": "BRELDOCTF002",
#         "deliberado_em": "02/10/2020",
#         "valor": "0,22000000000",
#         "relativo": "Outubro/2020",
#         "inicio_pag": "13/10/2020"
#       },
#       {
#         "isin": "BRELDOCTF002",
#         "deliberado_em": "28/09/2020",
#         "valor": "1,08000000000",
#         "relativo": "Setembro/2020",
#         "inicio_pag": "06/10/2020"
#       },
#       {
#         "isin": "BRELDOCTF002",
#         "deliberado_em": "15/09/2020",
#         "valor": "1,56000000000",
#         "relativo": "Setembro/2020",
#         "inicio_pag": "23/09/2020"
#       },
#       {
#         "isin": "BRELDOCTF002",
#         "deliberado_em": "04/09/2020",
#         "valor": "0,18000000000",
#         "relativo": "Setembro/2020",
#         "inicio_pag": "15/09/2020"
#       },
#       {
#         "isin": "BRELDOCTF002",
#         "deliberado_em": "28/08/2020",
#         "valor": "1,10000000000",
#         "relativo": "Agosto/2020",
#         "inicio_pag": "08/09/2020"
#       },
#       {
#         "isin": "BRELDOCTF002",
#         "deliberado_em": "13/08/2020",
#         "valor": "0,91000000000",
#         "relativo": "Agosto/2020",
#         "inicio_pag": "21/08/2020"
#       },
#       {
#         "isin": "BRELDOCTF002",
#         "deliberado_em": "15/07/2020",
#         "valor": "1,13000000000",
#         "relativo": "Julho/2020",
#         "inicio_pag": "23/07/2020"
#       },
#       {
#         "isin": "BRELDOCTF002",
#         "deliberado_em": "11/03/2020",
#         "valor": "4,30000000000",
#         "relativo": "Mar\u00e7o/2020",
#         "inicio_pag": "19/03/2020"
#       },
#       {
#         "isin": "BRELDOCTF002",
#         "deliberado_em": "02/03/2020",
#         "valor": "1,33000000000",
#         "relativo": "Mar\u00e7o/2020",
#         "inicio_pag": "10/03/2020"
#       },
#       {
#         "isin": "BRELDOCTF002",
#         "deliberado_em": "12/02/2020",
#         "valor": "4,60000000000",
#         "relativo": "Fevereiro/2020",
#         "inicio_pag": "20/02/2020"
#       },
#       {
#         "isin": "BRELDOCTF002",
#         "deliberado_em": "31/01/2020",
#         "valor": "2,09000000000",
#         "relativo": "Janeiro/2020",
#         "inicio_pag": "10/02/2020"
#       },
#       {
#         "isin": "BRELDOCTF002",
#         "deliberado_em": "15/01/2020",
#         "valor": "8,51000000000",
#         "relativo": "Janeiro/2020",
#         "inicio_pag": "23/01/2020"
#       },
#       {
#         "isin": "BRELDOCTF002",
#         "deliberado_em": "20/12/2019",
#         "valor": "0,95000000000",
#         "relativo": "dezembro/2019",
#         "inicio_pag": "07/01/2020"
#       },
#       {
#         "isin": "BRELDOCTF002",
#         "deliberado_em": "30/12/2019",
#         "valor": "1,01000000000",
#         "relativo": "Dezembro/2019",
#         "inicio_pag": "09/01/2020"
#       },
#       {
#         "isin": "BRELDOCTF002",
#         "deliberado_em": "13/12/2019",
#         "valor": "5,53000000000",
#         "relativo": "Dezembro/2019",
#         "inicio_pag": "23/12/2019"
#       },
#       {
#         "isin": "BRELDOCTF002",
#         "deliberado_em": "29/11/2019",
#         "valor": "2,54000000000",
#         "relativo": "Novembro/2019",
#         "inicio_pag": "09/12/2019"
#       },
#       {
#         "isin": "BRELDOCTF002",
#         "deliberado_em": "13/11/2019",
#         "valor": "5,95000000000",
#         "relativo": "Novembro/2019",
#         "inicio_pag": "25/11/2019"
#       },
#       {
#         "isin": "BRELDOCTF002",
#         "deliberado_em": "04/11/2019",
#         "valor": "1,46000000000",
#         "relativo": "Outubro/2019",
#         "inicio_pag": "12/11/2019"
#       },
#       {
#         "isin": "BRELDOCTF002",
#         "deliberado_em": "15/10/2019",
#         "valor": "5,02000000000",
#         "relativo": "Outubro/2019",
#         "inicio_pag": "23/10/2019"
#       }
#     ]
#   },
#   {
#     "fundo": "FII FLORIPA ",
#     "segmento": "BOLSA",
#     "codigo": "FLRP",
#     "lote": "1",
#     "cotacao": "02/05/2017",
#     "qtcotas": "65.232",
#     "formacotas": "Escritural - BTG PACTUAL SERVI\u00c7OS FINANC. S.A. DTVM",
#     "proventos": [
#       {
#         "isin": "BRFLRPCTF006",
#         "deliberado_em": "18/09/2020",
#         "valor": "1,74360804500",
#         "relativo": "Agosto/2020",
#         "inicio_pag": "30/09/2020"
#       },
#       {
#         "isin": "BRFLRPCTF006",
#         "deliberado_em": "20/08/2020",
#         "valor": "4,96024918200",
#         "relativo": "Julho/2020",
#         "inicio_pag": "31/08/2020"
#       },
#       {
#         "isin": "BRFLRPR06M19",
#         "deliberado_em": "20/08/2020",
#         "valor": "1,37929490600",
#         "relativo": "Julho/2020",
#         "inicio_pag": "31/08/2020"
#       },
#       {
#         "isin": "BRFLRPCTF006",
#         "deliberado_em": "20/07/2020",
#         "valor": "22,64837866700",
#         "relativo": "Junho/2020",
#         "inicio_pag": "31/07/2020"
#       },
#       {
#         "isin": "BRFLRPCTF006",
#         "deliberado_em": "19/02/2020",
#         "valor": "13,51590203100",
#         "relativo": "Janeiro/2020",
#         "inicio_pag": "28/02/2020"
#       },
#       {
#         "isin": "BRFLRPCTF006",
#         "deliberado_em": "20/01/2020",
#         "valor": "8,17189216700",
#         "relativo": "Dezembro/2019",
#         "inicio_pag": "27/01/2020"
#       },
#       {
#         "isin": "BRFLRPCTF006",
#         "deliberado_em": "19/12/2019",
#         "valor": "7,73424977000",
#         "relativo": "Novembro/2019",
#         "inicio_pag": "30/12/2019"
#       },
#       {
#         "isin": "BRFLRPCTF006",
#         "deliberado_em": "21/11/2019",
#         "valor": "7,25506762500",
#         "relativo": "Outubro/2019",
#         "inicio_pag": "28/11/2019"
#       },
#       {
#         "isin": "BRFLRPCTF006",
#         "deliberado_em": "18/10/2019",
#         "valor": "6,38746876900",
#         "relativo": "Setembro/2019",
#         "inicio_pag": "25/10/2019"
#       },
#       {
#         "isin": "BRFLRPR05M10",
#         "deliberado_em": "18/10/2019",
#         "valor": "3,52347065200",
#         "relativo": "Setembro/2019",
#         "inicio_pag": "25/10/2019"
#       }
#     ]
#   },
#   {
#     "fundo": "FII CRIANCA ",
#     "segmento": "BOLSA",
#     "codigo": "HCRI",
#     "lote": "1",
#     "cotacao": "02/05/2017",
#     "qtcotas": "200.000",
#     "formacotas": "Escritural - BTG PACTUAL SERVI\u00c7OS FINANC. S.A. DTVM",
#     "proventos": [
#       {
#         "isin": "BRHCRICTF006",
#         "deliberado_em": "11/09/2020",
#         "valor": "2,60121410000",
#         "relativo": "Agosto/2020",
#         "inicio_pag": "18/09/2020"
#       },
#       {
#         "isin": "BRHCRICTF006",
#         "deliberado_em": "13/08/2020",
#         "valor": "2,55406430000",
#         "relativo": "Julho/2020",
#         "inicio_pag": "20/08/2020"
#       },
#       {
#         "isin": "BRHCRICTF006",
#         "deliberado_em": "13/07/2020",
#         "valor": "2,70439625000",
#         "relativo": "Junho/2020",
#         "inicio_pag": "20/07/2020"
#       },
#       {
#         "isin": "BRHCRICTF006",
#         "deliberado_em": "12/06/2020",
#         "valor": "2,62927260000",
#         "relativo": "Maio/2020",
#         "inicio_pag": "19/06/2020"
#       },
#       {
#         "isin": "BRHCRICTF006",
#         "deliberado_em": "13/05/2020",
#         "valor": "2,65264380000",
#         "relativo": "Abril/2020",
#         "inicio_pag": "20/05/2020"
#       },
#       {
#         "isin": "BRHCRICTF006",
#         "deliberado_em": "13/04/2020",
#         "valor": "2,41227655000",
#         "relativo": "Mar\u00e7o/2020",
#         "inicio_pag": "20/04/2020"
#       },
#       {
#         "isin": "BRHCRICTF006",
#         "deliberado_em": "13/03/2020",
#         "valor": "2,62593760000",
#         "relativo": "Fevereiro/2020",
#         "inicio_pag": "20/03/2020"
#       },
#       {
#         "isin": "BRHCRICTF006",
#         "deliberado_em": "13/02/2020",
#         "valor": "2,65394280000",
#         "relativo": "Janeiro/2020",
#         "inicio_pag": "20/02/2020"
#       },
#       {
#         "isin": "BRHCRICTF006",
#         "deliberado_em": "13/01/2020",
#         "valor": "2,65038100000",
#         "relativo": "Dezembro/2019",
#         "inicio_pag": "20/01/2020"
#       },
#       {
#         "isin": "BRHCRICTF006",
#         "deliberado_em": "13/12/2019",
#         "valor": "2,65030395000",
#         "relativo": "Novembro/2019",
#         "inicio_pag": "20/12/2019"
#       },
#       {
#         "isin": "BRHCRICTF006",
#         "deliberado_em": "11/11/2019",
#         "valor": "2,63600090000",
#         "relativo": "Outubro/2019",
#         "inicio_pag": "19/11/2019"
#       },
#       {
#         "isin": "BRHCRICTF006",
#         "deliberado_em": "11/10/2019",
#         "valor": "2,56766520000",
#         "relativo": "Setembro/2019",
#         "inicio_pag": "18/10/2019"
#       }
#     ]
#   },
#   {
#     "fundo": "FII LOURDES ",
#     "segmento": "BOLSA",
#     "codigo": "NSLU",
#     "lote": "1",
#     "cotacao": "02/05/2017",
#     "qtcotas": "1.144.800",
#     "formacotas": "Escritural - BTG PACTUAL SERVI\u00c7OS FINANC. S.A. DTVM",
#     "proventos": [
#       {
#         "isin": "BRNSLUCTF008",
#         "deliberado_em": "30/09/2020",
#         "valor": "1,81095288200",
#         "relativo": "Agosto/2020",
#         "inicio_pag": "07/10/2020"
#       },
#       {
#         "isin": "BRNSLUCTF008",
#         "deliberado_em": "31/08/2020",
#         "valor": "1,68952960300",
#         "relativo": "Julho/2020",
#         "inicio_pag": "08/09/2020"
#       },
#       {
#         "isin": "BRNSLUCTF008",
#         "deliberado_em": "31/07/2020",
#         "valor": "3,97051237700",
#         "relativo": "Junho/2020",
#         "inicio_pag": "07/08/2020"
#       },
#       {
#         "isin": "BRNSLUCTF008",
#         "deliberado_em": "30/06/2020",
#         "valor": "3,93145157200",
#         "relativo": "Maio/2020",
#         "inicio_pag": "07/07/2020"
#       },
#       {
#         "isin": "BRNSLUCTF008",
#         "deliberado_em": "29/05/2020",
#         "valor": "1,74438086100",
#         "relativo": "Abril/2020",
#         "inicio_pag": "05/06/2020"
#       },
#       {
#         "isin": "BRNSLUCTF008",
#         "deliberado_em": "30/04/2020",
#         "valor": "1,65168869600",
#         "relativo": "Mar\u00e7o/2020",
#         "inicio_pag": "08/05/2020"
#       },
#       {
#         "isin": "BRNSLUCTF008",
#         "deliberado_em": "31/03/2020",
#         "valor": "1,69405052400",
#         "relativo": "Fevereiro/2020",
#         "inicio_pag": "07/04/2020"
#       },
#       {
#         "isin": "BRNSLUCTF008",
#         "deliberado_em": "28/02/2020",
#         "valor": "1,69157683400",
#         "relativo": "Janeiro/2020",
#         "inicio_pag": "06/03/2020"
#       },
#       {
#         "isin": "BRNSLUCTF008",
#         "deliberado_em": "31/01/2020",
#         "valor": "1,61820243700",
#         "relativo": "Dezembro/2019",
#         "inicio_pag": "07/02/2020"
#       },
#       {
#         "isin": "BRNSLUCTF008",
#         "deliberado_em": "30/12/2019",
#         "valor": "1,70434302000",
#         "relativo": "Novembro/2019",
#         "inicio_pag": "08/01/2020"
#       },
#       {
#         "isin": "BRNSLUCTF008",
#         "deliberado_em": "29/11/2019",
#         "valor": "1,63429583300",
#         "relativo": "Outubro/2019",
#         "inicio_pag": "06/12/2019"
#       },
#       {
#         "isin": "BRNSLUCTF008",
#         "deliberado_em": "31/10/2019",
#         "valor": "1,70654079300",
#         "relativo": "Setembro/2019",
#         "inicio_pag": "07/11/2019"
#       }
#     ]
#   },
#   {
#     "fundo": "FII HOTEL MX",
#     "segmento": "BOLSA",
#     "codigo": "HTMX",
#     "lote": "1",
#     "cotacao": "02/05/2017",
#     "qtcotas": "1.257.022",
#     "formacotas": "Escritural - BTG PACTUAL SERVI\u00c7OS FINANC. S.A. DTVM",
#     "proventos": [
#       {
#         "isin": "BRHTMXCTF000",
#         "deliberado_em": "28/02/2020",
#         "valor": "0,71239141300",
#         "relativo": "Fevereiro/2020",
#         "inicio_pag": "06/03/2020"
#       },
#       {
#         "isin": "BRHTMXCTF000",
#         "deliberado_em": "31/01/2020",
#         "valor": "0,58271402500",
#         "relativo": "Janeiro/2020",
#         "inicio_pag": "07/02/2020"
#       },
#       {
#         "isin": "BRHTMXCTF000",
#         "deliberado_em": "30/12/2019",
#         "valor": "0,46699298000",
#         "relativo": "Dezembro/2019",
#         "inicio_pag": "08/01/2020"
#       },
#       {
#         "isin": "BRHTMXCTF000",
#         "deliberado_em": "29/11/2019",
#         "valor": "0,98143061500",
#         "relativo": "Novembro/2019",
#         "inicio_pag": "06/12/2019"
#       },
#       {
#         "isin": "BRHTMXR03M17",
#         "deliberado_em": "29/11/2019",
#         "valor": "0,22206959200",
#         "relativo": "Novembro/2019",
#         "inicio_pag": "06/12/2019"
#       },
#       {
#         "isin": "BRHTMXCTF000",
#         "deliberado_em": "31/10/2019",
#         "valor": "1,04240261400",
#         "relativo": "Outubro/2019",
#         "inicio_pag": "07/11/2019"
#       }
#     ]
#   },
#   {
#     "fundo": "FII MAX RET ",
#     "segmento": "BOLSA",
#     "codigo": "MAXR",
#     "lote": "1",
#     "cotacao": "02/05/2017",
#     "qtcotas": "59.245",
#     "formacotas": "Escritural - BTG PACTUAL SERVI\u00c7OS FINANC. S.A. DTVM",
#     "proventos": [
#       {
#         "isin": "BRMAXRCTF009",
#         "deliberado_em": "08/09/2020",
#         "valor": "10,99958825200",
#         "relativo": "Julho/2020",
#         "inicio_pag": "15/09/2020"
#       },
#       {
#         "isin": "BRMAXRCTF009",
#         "deliberado_em": "07/08/2020",
#         "valor": "26,21096774400",
#         "relativo": "Junho/2020",
#         "inicio_pag": "14/08/2020"
#       },
#       {
#         "isin": "BRMAXRCTF009",
#         "deliberado_em": "07/07/2020",
#         "valor": "11,27218312900",
#         "relativo": "Maio/2020",
#         "inicio_pag": "14/07/2020"
#       },
#       {
#         "isin": "BRMAXRCTF009",
#         "deliberado_em": "07/04/2020",
#         "valor": "12,53746307700",
#         "relativo": "Fevereiro/2020",
#         "inicio_pag": "15/04/2020"
#       },
#       {
#         "isin": "BRMAXRCTF009",
#         "deliberado_em": "06/03/2020",
#         "valor": "12,94881002600",
#         "relativo": "Janeiro/2020",
#         "inicio_pag": "13/03/2020"
#       },
#       {
#         "isin": "BRMAXRCTF009",
#         "deliberado_em": "07/02/2020",
#         "valor": "12,47865532900",
#         "relativo": "Dezembro/2019",
#         "inicio_pag": "14/02/2020"
#       },
#       {
#         "isin": "BRMAXRCTF009",
#         "deliberado_em": "08/01/2020",
#         "valor": "12,88296354100",
#         "relativo": "Novembro/2019",
#         "inicio_pag": "15/01/2020"
#       },
#       {
#         "isin": "BRMAXRCTF009",
#         "deliberado_em": "06/12/2019",
#         "valor": "12,44630973000",
#         "relativo": "Outubro/2019",
#         "inicio_pag": "13/12/2019"
#       },
#       {
#         "isin": "BRMAXRCTF009",
#         "deliberado_em": "07/11/2019",
#         "valor": "13,50000000000",
#         "relativo": "Setembro/2019",
#         "inicio_pag": "14/11/2019"
#       },
#       {
#         "isin": "BRMAXRCTF009",
#         "deliberado_em": "07/10/2019",
#         "valor": "13,35784015500",
#         "relativo": "Agosto/2019",
#         "inicio_pag": "14/10/2019"
#       }
#     ]
#   },
#   {
#     "fundo": "FII NCH BRA ",
#     "segmento": "BOLSA",
#     "codigo": "NCHB",
#     "lote": "1",
#     "cotacao": "02/05/2017",
#     "qtcotas": "571.079",
#     "formacotas": "Escritural - BTG PACTUAL SERVI\u00c7OS FINANC. S.A. DTVM"
#   },
#   {
#     "fundo": "FII NOVOHORI",
#     "segmento": "BOLSA",
#     "codigo": "NVHO",
#     "lote": "1",
#     "cotacao": "04/10/2013",
#     "qtcotas": "41.494.533",
#     "formacotas": "Escritural - BRADESCO"
#   },
#   {
#     "fundo": "FII D PEDRO ",
#     "segmento": "BOLSA",
#     "codigo": "PQDP",
#     "lote": "1",
#     "cotacao": "17/12/2009",
#     "qtcotas": "238.477",
#     "formacotas": "Escritural - BTG PACTUAL SERVI\u00c7OS FINANC. S.A. DTVM"
#   },
#   {
#     "fundo": "FII PTO BAND",
#     "segmento": "BOLSA",
#     "codigo": "PATB",
#     "lote": "1",
#     "cotacao": "18/03/2019",
#     "qtcotas": "1.836.202",
#     "formacotas": "Escritural - BTG PACTUAL SERVI\u00c7OS FINANC. S.A. DTVM",
#     "proventos": [
#       {
#         "isin": "BRPATBCTF004",
#         "deliberado_em": "20/03/2020",
#         "valor": "3,72920981200",
#         "relativo": "Dezembro/2020",
#         "inicio_pag": "27/03/2020"
#       }
#     ]
#   },
#   {
#     "fundo": "FII RBR DES ",
#     "segmento": "BOLSA",
#     "codigo": "RBRM",
#     "lote": "1",
#     "cotacao": "30/07/2019",
#     "qtcotas": "541",
#     "formacotas": "Escritural - BTG PACTUAL SERVI\u00c7OS FINANC. S.A. DTVM"
#   },
#   {
#     "fundo": "FII RBRHGRAD",
#     "segmento": "BOLSA",
#     "codigo": "RBRR",
#     "lote": "1",
#     "cotacao": "20/03/2018",
#     "qtcotas": "6.942.557",
#     "formacotas": "Escritural - BTG PACTUAL SERVI\u00c7OS FINANC. S.A. DTVM",
#     "proventos": [
#       {
#         "isin": "BRRBRRCTF008",
#         "deliberado_em": "10/09/2020",
#         "valor": "0,50000000000",
#         "relativo": "Agosto/2020",
#         "inicio_pag": "17/09/2020"
#       },
#       {
#         "isin": "BRRBRRCTF008",
#         "deliberado_em": "07/08/2020",
#         "valor": "0,50000000000",
#         "relativo": "Julho/2020",
#         "inicio_pag": "14/08/2020"
#       },
#       {
#         "isin": "BRRBRRCTF008",
#         "deliberado_em": "09/07/2020",
#         "valor": "0,55000000000",
#         "relativo": "Junho/2020",
#         "inicio_pag": "16/07/2020"
#       },
#       {
#         "isin": "BRRBRRCTF008",
#         "deliberado_em": "09/06/2020",
#         "valor": "0,55000000000",
#         "relativo": "Maio/2020",
#         "inicio_pag": "17/06/2020"
#       },
#       {
#         "isin": "BRRBRRCTF008",
#         "deliberado_em": "12/05/2020",
#         "valor": "0,55000000000",
#         "relativo": "Abril/2020",
#         "inicio_pag": "19/05/2020"
#       },
#       {
#         "isin": "BRRBRRCTF008",
#         "deliberado_em": "09/04/2020",
#         "valor": "0,55000000000",
#         "relativo": "Mar\u00e7o/2020",
#         "inicio_pag": "17/04/2020"
#       },
#       {
#         "isin": "BRRBRRCTF008",
#         "deliberado_em": "10/03/2020",
#         "valor": "0,60000000000",
#         "relativo": "Fevereiro/2020",
#         "inicio_pag": "17/03/2020"
#       },
#       {
#         "isin": "BRRBRRCTF008",
#         "deliberado_em": "07/02/2020",
#         "valor": "0,59595190200",
#         "relativo": "Janeiro/2020",
#         "inicio_pag": "14/02/2020"
#       },
#       {
#         "isin": "BRRBRRCTF008",
#         "deliberado_em": "10/01/2020",
#         "valor": "0,60000000000",
#         "relativo": "Dezembro/2019",
#         "inicio_pag": "17/01/2020"
#       },
#       {
#         "isin": "BRRBRRCTF008",
#         "deliberado_em": "10/12/2019",
#         "valor": "0,55000000000",
#         "relativo": "Novembro/2019",
#         "inicio_pag": "17/12/2019"
#       },
#       {
#         "isin": "BRRBRRR08M13",
#         "deliberado_em": "10/12/2019",
#         "valor": "0,17086605400",
#         "relativo": "Novembro/2019",
#         "inicio_pag": "17/12/2019"
#       },
#       {
#         "isin": "BRRBRRCTF008",
#         "deliberado_em": "11/11/2019",
#         "valor": "0,54581775100",
#         "relativo": "Outubro/2019",
#         "inicio_pag": "19/11/2019"
#       },
#       {
#         "isin": "BRRBRRR06M15",
#         "deliberado_em": "11/11/2019",
#         "valor": "0,30316425800",
#         "relativo": "Outubro/2019",
#         "inicio_pag": "19/11/2019"
#       },
#       {
#         "isin": "BRRBRRR07M14",
#         "deliberado_em": "11/11/2019",
#         "valor": "0,18230450100",
#         "relativo": "Outubro/2019",
#         "inicio_pag": "19/11/2019"
#       },
#       {
#         "isin": "BRRBRRCTF008",
#         "deliberado_em": "09/10/2019",
#         "valor": "0,63000000000",
#         "relativo": "Setembro/2019",
#         "inicio_pag": "16/10/2019"
#       }
#     ]
#   },
#   {
#     "fundo": "FII REC RECE",
#     "segmento": "BOLSA",
#     "codigo": "RECR",
#     "lote": "1",
#     "cotacao": "18/09/2017",
#     "qtcotas": "7.249.687",
#     "formacotas": "Escritural - BRL TRUST DTVM S.A.",
#     "proventos": [
#       {
#         "isin": "BRRECRCTF004",
#         "deliberado_em": "08/09/2020",
#         "valor": "0,90000000000",
#         "relativo": "Agosto/2020",
#         "inicio_pag": "15/09/2020"
#       },
#       {
#         "isin": "BRRECRR01M14",
#         "deliberado_em": "08/09/2020",
#         "valor": "0,90000000000",
#         "relativo": "Agosto/2020",
#         "inicio_pag": "15/09/2020"
#       },
#       {
#         "isin": "BRRECRR02M13",
#         "deliberado_em": "08/09/2020",
#         "valor": "0,48500000000",
#         "relativo": "Agosto/2020",
#         "inicio_pag": "15/09/2020"
#       },
#       {
#         "isin": "BRRECRR03M12",
#         "deliberado_em": "08/09/2020",
#         "valor": "0,90000000000",
#         "relativo": "Agosto/2020",
#         "inicio_pag": "15/09/2020"
#       }
#     ]
#   },
#   {
#     "fundo": "FII REC REND",
#     "segmento": "BOLSA",
#     "codigo": "RECT",
#     "lote": "1",
#     "cotacao": "20/02/2019",
#     "qtcotas": "6.973.846",
#     "formacotas": "Escritural - BRL TRUST DTVM S.A.",
#     "proventos": [
#       {
#         "isin": "BRRECTCTF000",
#         "deliberado_em": "08/09/2020",
#         "valor": "0,72000000000",
#         "relativo": "Agosto/2020",
#         "inicio_pag": "15/09/2020"
#       },
#       {
#         "isin": "BRRECTCTF000",
#         "deliberado_em": "07/08/2020",
#         "valor": "0,81000000000",
#         "relativo": "Julho/2020",
#         "inicio_pag": "14/08/2020"
#       },
#       {
#         "isin": "BRRECTR13M18",
#         "deliberado_em": "07/08/2020",
#         "valor": "0,45780000000",
#         "relativo": "Julho/2020",
#         "inicio_pag": "14/08/2020"
#       },
#       {
#         "isin": "BRRECTR14M17",
#         "deliberado_em": "07/08/2020",
#         "valor": "0,14090000000",
#         "relativo": "Julho/2020",
#         "inicio_pag": "14/08/2020"
#       },
#       {
#         "isin": "BRRECTCTF000",
#         "deliberado_em": "07/07/2020",
#         "valor": "0,81000000000",
#         "relativo": "Junho/2020",
#         "inicio_pag": "14/07/2020"
#       },
#       {
#         "isin": "BRRECTR08M15",
#         "deliberado_em": "07/07/2020",
#         "valor": "0,81000000000",
#         "relativo": "Junho/2020",
#         "inicio_pag": "14/07/2020"
#       },
#       {
#         "isin": "BRRECTR09M14",
#         "deliberado_em": "07/07/2020",
#         "valor": "0,81000000000",
#         "relativo": "Junho/2020",
#         "inicio_pag": "14/07/2020"
#       },
#       {
#         "isin": "BRRECTR10M11",
#         "deliberado_em": "07/07/2020",
#         "valor": "0,69430000000",
#         "relativo": "Junho/2020",
#         "inicio_pag": "14/07/2020"
#       },
#       {
#         "isin": "BRRECTR11M10",
#         "deliberado_em": "07/07/2020",
#         "valor": "0,50140000000",
#         "relativo": "Junho/2020",
#         "inicio_pag": "14/07/2020"
#       },
#       {
#         "isin": "BRRECTR12M19",
#         "deliberado_em": "07/07/2020",
#         "valor": "0,34710000000",
#         "relativo": "Junho/2020",
#         "inicio_pag": "14/07/2020"
#       },
#       {
#         "isin": "BRRECTCTF000",
#         "deliberado_em": "05/06/2020",
#         "valor": "0,81000000000",
#         "relativo": "Maio/2020",
#         "inicio_pag": "15/06/2020"
#       },
#       {
#         "isin": "BRRECTR08M15",
#         "deliberado_em": "05/06/2020",
#         "valor": "0,44550000000",
#         "relativo": "Maio/2020",
#         "inicio_pag": "15/06/2020"
#       },
#       {
#         "isin": "BRRECTR09M14",
#         "deliberado_em": "05/06/2020",
#         "valor": "0,08100000000",
#         "relativo": "Maio/2020",
#         "inicio_pag": "15/06/2020"
#       },
#       {
#         "isin": "BRRECTCTF000",
#         "deliberado_em": "08/05/2020",
#         "valor": "0,81000000000",
#         "relativo": "Abril/2020",
#         "inicio_pag": "15/05/2020"
#       },
#       {
#         "isin": "BRRECTCTF000",
#         "deliberado_em": "07/04/2020",
#         "valor": "0,81000000000",
#         "relativo": "Mar\u00e7o/2020",
#         "inicio_pag": "15/04/2020"
#       },
#       {
#         "isin": "BRRECTR04M19",
#         "deliberado_em": "07/04/2020",
#         "valor": "0,81000000000",
#         "relativo": "mar\u00e7o/2020",
#         "inicio_pag": "15/04/2020"
#       },
#       {
#         "isin": "BRRECTR05M18",
#         "deliberado_em": "07/04/2020",
#         "valor": "0,81000000000",
#         "relativo": "Mar\u00e7o/2020",
#         "inicio_pag": "15/04/2020"
#       },
#       {
#         "isin": "BRRECTR06M17",
#         "deliberado_em": "07/04/2020",
#         "valor": "0,11050000000",
#         "relativo": "Mar\u00e7o/2020",
#         "inicio_pag": "15/04/2020"
#       },
#       {
#         "isin": "BRRECTCTF000",
#         "deliberado_em": "06/03/2020",
#         "valor": "0,84370000000",
#         "relativo": "Fevereiro/2020",
#         "inicio_pag": "13/03/2020"
#       },
#       {
#         "isin": "BRRECTR04M19",
#         "deliberado_em": "06/03/2020",
#         "valor": "0,70230000000",
#         "relativo": "Fevereiro/2020",
#         "inicio_pag": "13/03/2020"
#       },
#       {
#         "isin": "BRRECTR05M18",
#         "deliberado_em": "06/03/2020",
#         "valor": "0,14090000000",
#         "relativo": "Fevereiro/2020",
#         "inicio_pag": "13/03/2020"
#       },
#       {
#         "isin": "BRRECTCTF000",
#         "deliberado_em": "07/02/2020",
#         "valor": "0,81000000000",
#         "relativo": "Janeiro/2020",
#         "inicio_pag": "14/02/2020"
#       },
#       {
#         "isin": "BRRECTCTF000",
#         "deliberado_em": "08/01/2020",
#         "valor": "0,81120000000",
#         "relativo": "Dezembro/2019",
#         "inicio_pag": "15/01/2020"
#       },
#       {
#         "isin": "BRRECTR02M11",
#         "deliberado_em": "08/01/2020",
#         "valor": "0,81120000000",
#         "relativo": "Dezembro/2019",
#         "inicio_pag": "15/01/2020"
#       },
#       {
#         "isin": "BRRECTR03M10",
#         "deliberado_em": "08/01/2020",
#         "valor": "0,31220000000",
#         "relativo": "Dezembro/2019",
#         "inicio_pag": "15/01/2020"
#       },
#       {
#         "isin": "BRRECTCTF000",
#         "deliberado_em": "06/12/2019",
#         "valor": "0,75090000000",
#         "relativo": "Novembro/2019",
#         "inicio_pag": "13/12/2019"
#       },
#       {
#         "isin": "BRRECTR02M11",
#         "deliberado_em": "06/12/2019",
#         "valor": "0,31960000000",
#         "relativo": "Novembro/2019",
#         "inicio_pag": "13/12/2019"
#       },
#       {
#         "isin": "BRRECTCTF000",
#         "deliberado_em": "07/11/2019",
#         "valor": "1,57000000000",
#         "relativo": "Outubro/2019",
#         "inicio_pag": "14/11/2019"
#       },
#       {
#         "isin": "BRRECTCTF000",
#         "deliberado_em": "07/10/2019",
#         "valor": "1,00000000000",
#         "relativo": "Setembro/2019",
#         "inicio_pag": "14/10/2019"
#       }
#     ]
#   },
#   {
#     "fundo": "FII SHOPJSUL",
#     "segmento": "BOLSA",
#     "codigo": "JRDM",
#     "lote": "1",
#     "cotacao": "02/05/2017",
#     "qtcotas": "2.522.968",
#     "formacotas": "Escritural - BTG PACTUAL SERVI\u00c7OS FINANC. S.A. DTVM",
#     "proventos": [
#       {
#         "isin": "BRJRDMCTF002",
#         "deliberado_em": "07/08/2020",
#         "valor": "0,16057129100",
#         "relativo": "Junho/2020",
#         "inicio_pag": "14/08/2020"
#       },
#       {
#         "isin": "BRJRDMCTF002",
#         "deliberado_em": "06/03/2020",
#         "valor": "0,39865104900",
#         "relativo": "Janeiro/2020",
#         "inicio_pag": "13/03/2020"
#       },
#       {
#         "isin": "BRJRDMCTF002",
#         "deliberado_em": "07/02/2020",
#         "valor": "0,81324141200",
#         "relativo": "Dezembro/2019",
#         "inicio_pag": "14/02/2020"
#       },
#       {
#         "isin": "BRJRDMCTF002",
#         "deliberado_em": "08/01/2020",
#         "valor": "0,49000000000",
#         "relativo": "Novembro/2019",
#         "inicio_pag": "15/01/2020"
#       },
#       {
#         "isin": "BRJRDMCTF002",
#         "deliberado_em": "06/12/2019",
#         "valor": "0,52000000000",
#         "relativo": "Outubro/2019",
#         "inicio_pag": "13/12/2019"
#       },
#       {
#         "isin": "BRJRDMCTF002",
#         "deliberado_em": "07/11/2019",
#         "valor": "0,48000000000",
#         "relativo": "Setembro/2019",
#         "inicio_pag": "14/11/2019"
#       },
#       {
#         "isin": "BRJRDMCTF002",
#         "deliberado_em": "07/10/2019",
# ...
#         "inicio_pag": "13/12/2019"
#       },
#       {
#         "isin": "BRXPCMCTF009",
#         "deliberado_em": "31/10/2019",
#         "valor": "0,81000000000",
#         "relativo": "Outubro/2019",
#         "inicio_pag": "14/11/2019"
#       }
#     ]
#   },
#   {
#     "fundo": "FII XP CRED ",
#     "segmento": "BOLSA",
#     "codigo": "XPCI",
#     "lote": "1",
#     "cotacao": "12/09/2019",
#     "qtcotas": "6.567.011",
#     "formacotas": "Escritural - VORTX DTVM LTDA.",
#     "proventos": [
#       {
#         "isin": "BRXPCICTF007",
#         "deliberado_em": "30/09/2020",
#         "valor": "0,58000000000",
#         "relativo": "09-2020/2020",
#         "inicio_pag": "15/10/2020"
#       },
#       {
#         "isin": "BRXPCICTF007",
#         "deliberado_em": "31/08/2020",
#         "valor": "0,60000000000",
#         "relativo": "08-2020/2020",
#         "inicio_pag": "15/09/2020"
#       },
#       {
#         "isin": "BRXPCICTF007",
#         "deliberado_em": "31/07/2020",
#         "valor": "0,57000000000",
#         "relativo": "07-2020/2020",
#         "inicio_pag": "14/08/2020"
#       },
#       {
#         "isin": "BRXPCICTF007",
#         "deliberado_em": "30/06/2020",
#         "valor": "0,54000000000",
#         "relativo": "06-2020/2020",
#         "inicio_pag": "15/07/2020"
#       },
#       {
#         "isin": "BRXPCICTF007",
#         "deliberado_em": "29/05/2020",
#         "valor": "0,54000000000",
#         "relativo": "05-2020/2020",
#         "inicio_pag": "15/06/2020"
#       },
#       {
#         "isin": "BRXPCICTF007",
#         "deliberado_em": "30/04/2020",
#         "valor": "0,57000000000",
#         "relativo": "04-2020/2020",
#         "inicio_pag": "15/05/2020"
#       },
#       {
#         "isin": "BRXPCICTF007",
#         "deliberado_em": "31/03/2020",
#         "valor": "0,61000000000",
#         "relativo": "03-2020/2020",
#         "inicio_pag": "14/04/2020"
#       },
#       {
#         "isin": "BRXPCICTF007",
#         "deliberado_em": "28/02/2020",
#         "valor": "0,65000000000",
#         "relativo": "02-2020/2020",
#         "inicio_pag": "13/03/2020"
#       },
#       {
#         "isin": "BRXPCIR02M13",
#         "deliberado_em": "28/02/2020",
#         "valor": "0,42000000000",
#         "relativo": "fevereiro/2020",
#         "inicio_pag": "13/03/2020"
#       },
#       {
#         "isin": "BRXPCIR03M12",
#         "deliberado_em": "28/02/2020",
#         "valor": "0,36000000000",
#         "relativo": "fevereiro/2020",
#         "inicio_pag": "13/03/2020"
#       },
#       {
#         "isin": "BRXPCIR04M11",
#         "deliberado_em": "28/02/2020",
#         "valor": "0,42000000000",
#         "relativo": "fevereiro/2020",
#         "inicio_pag": "13/03/2020"
#       },
#       {
#         "isin": "BRXPCIR04M11",
#         "deliberado_em": "05/02/2020",
#         "valor": "0,05000000000",
#         "relativo": "JANEIRO/2020",
#         "inicio_pag": "14/02/2020"
#       },
#       {
#         "isin": "BRXPCICTF007",
#         "deliberado_em": "31/01/2020",
#         "valor": "0,62000000000",
#         "relativo": "01-2020/2020",
#         "inicio_pag": "14/02/2020"
#       },
#       {
#         "isin": "BRXPCIR02M13",
#         "deliberado_em": "31/01/2020",
#         "valor": "0,14000000000",
#         "relativo": "janeiro/2020",
#         "inicio_pag": "14/02/2020"
#       },
#       {
#         "isin": "BRXPCIR03M12",
#         "deliberado_em": "31/01/2020",
#         "valor": "0,05000000000",
#         "relativo": "janeiro/2020",
#         "inicio_pag": "14/02/2020"
#       },
#       {
#         "isin": "BRXPCICTF007",
#         "deliberado_em": "30/12/2019",
#         "valor": "0,64000000000",
#         "relativo": "12-2019/2019",
#         "inicio_pag": "15/01/2020"
#       },
#       {
#         "isin": "BRXPCIR01M14",
#         "deliberado_em": "29/11/2019",
#         "valor": "0,63000000000",
#         "relativo": "Novembro/2019",
#         "inicio_pag": "13/12/2019"
#       },
#       {
#         "isin": "BRXPCIR01M14",
#         "deliberado_em": "31/10/2019",
#         "valor": "0,63000000000",
#         "relativo": "10-2019/2019",
#         "inicio_pag": "14/11/2019"
#       }
#     ]
#   },
#   {
#     "fundo": "FII XP HOT  ",
#     "segmento": "BOLSA",
#     "codigo": "XPHT",
#     "lote": "1",
#     "cotacao": "17/12/2018",
#     "qtcotas": "3.737.642",
#     "formacotas": "Escritural - ITAU CORRETORA ACOES",
#     "proventos": [
#       {
#         "isin": "BRXPHTCTF003",
#         "deliberado_em": "31/03/2020",
#         "valor": "0,34028598000",
#         "relativo": "Mar\u00e7o/2020",
#         "inicio_pag": "15/04/2020"
#       },
#       {
#         "isin": "BRXPHTCTF003",
#         "deliberado_em": "28/02/2020",
#         "valor": "0,29468163000",
#         "relativo": "Fevereiro/2020",
#         "inicio_pag": "13/03/2020"
#       },
#       {
#         "isin": "BRXPHTCTF011",
#         "deliberado_em": "28/02/2020",
#         "valor": "0,50000000000",
#         "relativo": "Fevereiro/2020",
#         "inicio_pag": "13/03/2020"
#       },
#       {
#         "isin": "BRXPHTCTF003",
#         "deliberado_em": "31/01/2020",
#         "valor": "0,37662362900",
#         "relativo": "Janeiro/2020",
#         "inicio_pag": "14/02/2020"
#       },
#       {
#         "isin": "BRXPHTCTF011",
#         "deliberado_em": "31/01/2020",
#         "valor": "0,50000000000",
#         "relativo": "Janeiro/2020",
#         "inicio_pag": "14/02/2020"
#       },
#       {
#         "isin": "BRXPHTCTF003",
#         "deliberado_em": "30/12/2019",
#         "valor": "0,37660015600",
#         "relativo": "Dezembro/2019",
#         "inicio_pag": "15/01/2020"
#       },
#       {
#         "isin": "BRXPHTCTF011",
#         "deliberado_em": "30/12/2019",
#         "valor": "0,91000000000",
#         "relativo": "Dezembro/2019",
#         "inicio_pag": "15/01/2020"
#       },
#       {
#         "isin": "BRXPHTCTF003",
#         "deliberado_em": "29/11/2019",
#         "valor": "0,38038297100",
#         "relativo": "Novembro/2019",
#         "inicio_pag": "13/12/2019"
#       },
#       {
#         "isin": "BRXPHTCTF011",
#         "deliberado_em": "29/11/2019",
#         "valor": "0,80000000000",
#         "relativo": "Novembro/2019",
#         "inicio_pag": "13/12/2019"
#       },
#       {
#         "isin": "BRXPHTCTF003",
#         "deliberado_em": "31/10/2019",
#         "valor": "0,48116435300",
#         "relativo": "Outubro/2019",
#         "inicio_pag": "14/11/2019"
#       },
#       {
#         "isin": "BRXPHTCTF011",
#         "deliberado_em": "31/10/2019",
#         "valor": "0,75000000000",
#         "relativo": "Outubro/2019",
#         "inicio_pag": "14/11/2019"
#       }
#     ]
#   },
#   {
#     "fundo": "FII XP INDL ",
#     "segmento": "BOLSA",
#     "codigo": "XPIN",
#     "lote": "1",
#     "cotacao": "03/07/2018",
#     "qtcotas": "6.586.568",
#     "formacotas": "Escritural - VORTX DTVM LTDA.",
#     "proventos": [
#       {
#         "isin": "BRXPINCTF004",
#         "deliberado_em": "18/09/2020",
#         "valor": "0,62000000000",
#         "relativo": "08-2020/2020",
#         "inicio_pag": "25/09/2020"
#       },
#       {
#         "isin": "BRXPINCTF004",
#         "deliberado_em": "13/08/2020",
#         "valor": "0,62000000000",
#         "relativo": "07-2020/2020",
#         "inicio_pag": "20/08/2020"
#       },
#       {
#         "isin": "BRXPINCTF004",
#         "deliberado_em": "17/07/2020",
#         "valor": "0,60000000000",
#         "relativo": "06-2020/2020",
#         "inicio_pag": "24/07/2020"
#       },
#       {
#         "isin": "BRXPINCTF004",
#         "deliberado_em": "18/06/2020",
#         "valor": "0,60000000000",
#         "relativo": "05-2020/2020",
#         "inicio_pag": "25/06/2020"
#       },
#       {
#         "isin": "BRXPINCTF004",
#         "deliberado_em": "18/05/2020",
#         "valor": "0,56000000000",
#         "relativo": "04-2020/2020",
#         "inicio_pag": "25/05/2020"
#       },
#       {
#         "isin": "BRXPINCTF004",
#         "deliberado_em": "16/04/2020",
#         "valor": "0,56000000000",
#         "relativo": "03-2020/2020",
#         "inicio_pag": "24/04/2020"
#       },
#       {
#         "isin": "BRXPINCTF004",
#         "deliberado_em": "18/03/2020",
#         "valor": "0,71000000000",
#         "relativo": "02-2020/2020",
#         "inicio_pag": "25/03/2020"
#       },
#       {
#         "isin": "BRXPINR06M16",
#         "deliberado_em": "18/03/2020",
#         "valor": "0,15000000000",
#         "relativo": "FEVEREIRO/2020",
#         "inicio_pag": "25/03/2020"
#       },
#       {
#         "isin": "BRXPINCTF004",
#         "deliberado_em": "07/02/2020",
#         "valor": "0,71000000000",
#         "relativo": "01-2020/2020",
#         "inicio_pag": "14/02/2020"
#       },
#       {
#         "isin": "BRXPINCTF004",
#         "deliberado_em": "17/01/2020",
#         "valor": "0,72000000000",
#         "relativo": "12-2019/2019",
#         "inicio_pag": "24/01/2020"
#       },
#       {
#         "isin": "BRXPINCTF004",
#         "deliberado_em": "17/12/2019",
#         "valor": "0,72000000000",
#         "relativo": "Novembro/2019",
#         "inicio_pag": "23/12/2019"
#       },
#       {
#         "isin": "BRXPINCTF004",
#         "deliberado_em": "14/11/2019",
#         "valor": "0,72000000000",
#         "relativo": "Outubro/2019",
#         "inicio_pag": "25/11/2019"
#       },
#       {
#         "isin": "BRXPINCTF004",
#         "deliberado_em": "18/10/2019",
#         "valor": "0,72000000000",
#         "relativo": "Setembro/2019",
#         "inicio_pag": "25/10/2019"
#       }
#     ]
#   },
#   {
#     "fundo": "FII XP LOG  ",
#     "segmento": "BOLSA",
#     "codigo": "XPLG",
#     "lote": "1",
#     "cotacao": "26/04/2018",
#     "qtcotas": "20.757.449",
#     "formacotas": "Escritural - OLIVEIRA TRUST"
#   },
#   {
#     "fundo": "FII XP MALLS",
#     "segmento": "BOLSA",
#     "codigo": "XPML",
#     "lote": "1",
#     "cotacao": "23/11/2017",
#     "qtcotas": "18.207.683",
#     "formacotas": "Escritural - BTG PACTUAL SERVI\u00c7OS FINANC. S.A. DTVM",
#     "proventos": [
#       {
#         "isin": "BRXPMLCTF000",
#         "deliberado_em": "18/09/2020",
#         "valor": "0,18000000000",
#         "relativo": "Agosto/2020",
#         "inicio_pag": "25/09/2020"
#       },
#       {
#         "isin": "BRXPMLCTF000",
#         "deliberado_em": "18/08/2020",
#         "valor": "0,03000000000",
#         "relativo": "Julho/2020",
#         "inicio_pag": "25/08/2020"
#       },
#       {
#         "isin": "BRXPMLCTF000",
#         "deliberado_em": "17/07/2020",
#         "valor": "0,41505259200",
#         "relativo": "Junho/2020",
#         "inicio_pag": "24/07/2020"
#       },
#       {
#         "isin": "BRXPMLCTF000",
#         "deliberado_em": "18/06/2020",
#         "valor": "0,27000000000",
#         "relativo": "Maio/2020",
#         "inicio_pag": "25/06/2020"
#       },
#       {
#         "isin": "BRXPMLCTF000",
#         "deliberado_em": "14/02/2020",
#         "valor": "0,50000000000",
#         "relativo": "Janeiro/2020",
#         "inicio_pag": "21/02/2020"
#       },
#       {
#         "isin": "BRXPMLCTF000",
#         "deliberado_em": "17/01/2020",
#         "valor": "0,61000000000",
#         "relativo": "Dezembro/2019",
#         "inicio_pag": "24/01/2020"
#       },
#       {
#         "isin": "BRXPMLCTF000",
#         "deliberado_em": "16/12/2019",
#         "valor": "0,52000000000",
#         "relativo": "Novembro/2019",
#         "inicio_pag": "23/12/2019"
#       },
#       {
#         "isin": "BRXPMLCTF000",
#         "deliberado_em": "14/11/2019",
#         "valor": "0,59000000000",
#         "relativo": "Outubro/2019",
#         "inicio_pag": "25/11/2019"
#       },
#       {
#         "isin": "BRXPMLR13M13",
#         "deliberado_em": "14/11/2019",
#         "valor": "0,59000000000",
#         "relativo": "Outubro/2019",
#         "inicio_pag": "25/11/2019"
#       },
#       {
#         "isin": "BRXPMLR14M12",
#         "deliberado_em": "14/11/2019",
#         "valor": "0,13879005600",
#         "relativo": "Outubro/2019",
#         "inicio_pag": "25/11/2019"
#       },
#       {
#         "isin": "BRXPMLCTF000",
#         "deliberado_em": "18/10/2019",
#         "valor": "0,59000000000",
#         "relativo": "Setembro/2019",
#         "inicio_pag": "25/10/2019"
#       },
#       {
#         "isin": "BRXPMLR13M13",
#         "deliberado_em": "18/10/2019",
#         "valor": "0,59000000000",
#         "relativo": "Setembro/2019",
#         "inicio_pag": "25/10/2019"
#       }
#     ]
#   },
#   {
#     "fundo": "FII XP PROP ",
#     "segmento": "BOLSA",
#     "codigo": "XPPR",
#     "lote": "1",
#     "cotacao": "01/11/2019",
#     "qtcotas": "4.320.000",
#     "formacotas": "Escritural - VORTX DTVM LTDA.",
#     "proventos": [
#       {
#         "isin": "BRXPPRCTF000",
#         "deliberado_em": "30/09/2020",
#         "valor": "0,74000000000",
#         "relativo": "09-2020/2020",
#         "inicio_pag": "15/10/2020"
#       },
#       {
#         "isin": "BRXPPRCTF000",
#         "deliberado_em": "31/08/2020",
#         "valor": "0,72000000000",
#         "relativo": "08-2020/2020",
#         "inicio_pag": "15/09/2020"
#       },
#       {
#         "isin": "BRXPPRCTF000",
#         "deliberado_em": "31/07/2020",
#         "valor": "0,70000000000",
#         "relativo": "07-2020/2020",
#         "inicio_pag": "14/08/2020"
#       },
#       {
#         "isin": "BRXPPRCTF000",
#         "deliberado_em": "30/06/2020",
#         "valor": "0,93000000000",
#         "relativo": "06-2020/2020",
#         "inicio_pag": "15/07/2020"
#       },
#       {
#         "isin": "BRXPPRCTF000",
#         "deliberado_em": "29/05/2020",
#         "valor": "0,80000000000",
#         "relativo": "05-2020/2020",
#         "inicio_pag": "15/06/2020"
#       },
#       {
#         "isin": "BRXPPRCTF000",
#         "deliberado_em": "30/04/2020",
#         "valor": "0,50000000000",
#         "relativo": "04-2020/2020",
#         "inicio_pag": "15/05/2020"
#       },
#       {
#         "isin": "BRXPPRCTF000",
#         "deliberado_em": "31/03/2020",
#         "valor": "0,50000000000",
#         "relativo": "03-2020/2020",
#         "inicio_pag": "14/04/2020"
#       },
#       {
#         "isin": "BRXPPRCTF000",
#         "deliberado_em": "28/02/2020",
#         "valor": "0,52000000000",
#         "relativo": "02-2020/2020",
#         "inicio_pag": "13/03/2020"
#       },
#       {
#         "isin": "BRXPPRCTF000",
#         "deliberado_em": "31/01/2020",
#         "valor": "0,52000000000",
#         "relativo": "01-2020/2020",
#         "inicio_pag": "14/02/2020"
#       },
#       {
#         "isin": "BRXPPRCTF000",
#         "deliberado_em": "30/12/2019",
#         "valor": "0,55000000000",
#         "relativo": "12-2019/2019",
#         "inicio_pag": "15/01/2020"
#       }
#     ]
#   },
#   {
#     "fundo": "FII XP SELEC",
#     "segmento": "BOLSA",
#     "codigo": "XPSF",
#     "lote": "1",
#     "cotacao": "29/08/2019",
#     "qtcotas": "3.350.000",
#     "formacotas": "Escritural - VORTX DTVM LTDA.",
#     "proventos": [
#       {
#         "isin": "BRXPSFCTF009",
#         "deliberado_em": "31/08/2020",
#         "valor": "0,70000000000",
#         "relativo": "08-2020/2020",
#         "inicio_pag": "15/09/2020"
#       },
#       {
#         "isin": "BRXPSFCTF009",
#         "deliberado_em": "31/07/2020",
#         "valor": "0,70000000000",
#         "relativo": "07-2020/2020",
#         "inicio_pag": "14/08/2020"
#       },
#       {
#         "isin": "BRXPSFCTF009",
#         "deliberado_em": "30/06/2020",
#         "valor": "0,80000000000",
#         "relativo": "06-2020/2020",
#         "inicio_pag": "15/07/2020"
#       },
#       {
#         "isin": "BRXPSFCTF009",
#         "deliberado_em": "29/05/2020",
#         "valor": "0,67500000000",
#         "relativo": "05-2020/2020",
#         "inicio_pag": "15/06/2020"
#       },
#       {
#         "isin": "BRXPSFCTF009",
#         "deliberado_em": "30/04/2020",
#         "valor": "0,65000000000",
#         "relativo": "04-2020/2020",
#         "inicio_pag": "15/05/2020"
#       },
#       {
#         "isin": "BRXPSFCTF009",
#         "deliberado_em": "31/03/2020",
#         "valor": "0,65000000000",
#         "relativo": "03-2020/2020",
#         "inicio_pag": "14/04/2020"
#       },
#       {
#         "isin": "BRXPSFCTF009",
#         "deliberado_em": "28/02/2020",
#         "valor": "0,70000000000",
#         "relativo": "02-2020/2020",
#         "inicio_pag": "13/03/2020"
#       },
#       {
#         "isin": "BRXPSFCTF009",
#         "deliberado_em": "31/01/2020",
#         "valor": "0,52000000000",
#         "relativo": "Janeiro/2020",
#         "inicio_pag": "14/02/2020"
#       },
#       {
#         "isin": "BRXPSFCTF009",
#         "deliberado_em": "30/12/2019",
#         "valor": "3,70000000000",
#         "relativo": "dezembro/2019",
#         "inicio_pag": "15/01/2020"
#       }
#     ]
#   }
# ]

# %%
from google.colab import files
files.download('fiis.json')

# %%
#test
link = 'http://bvmf.bmfbovespa.com.br/Fundos-Listados/' + tabela[7].find('a')['href']
outros = urlopen(link)
soup_others = BeautifulSoup(outros, 'html.parser')

prov = soup_others.select('tbody tr')



for c in range(16, len(prov)):
  trat = prov[c].find('td').get_text()  
  if trat == 'RENDIMENTO':
    print(trat)
  #print(prov[c].find('td', align='left').get_text())
  #print(prov[c].find('td', align='center').get_text())
  #print(prov[c].find('td', align='right').get_text())
  #print(prov[c].find('td', align='center').find_next('td').find_next('td', align='center').get_text())
  #print(prov[c].find.find('td', align='center').find_next('td').find_next('td', align='center').find_next('td').get_text())
